# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

num_datasets=[10,40,80,200]
num_nodes=[2,10,40,100]

#Empty arrays for final training/validation errors (avg of shuffle errors)
final_train_error=np.zeros((4,4))
final_valid_error=np.zeros((4,4))

#Making early stop call back 75 epochs after validation loss starts to increase
#This is fine because the later code takes the minimum total error
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=75)

#Loop through all datasets
for i_datasets, datasets in enumerate(num_datasets):
    #Generating data and target data
    f1_xdata=np.array(2*np.random.rand(datasets)-1)
    f1_ydata=np.array(f1_xdata*np.sin(6*np.pi*f1_xdata)*np.exp(-f1_xdata**2))
    #Splitting data 80/20 training/testing
    f1train_x, f1test_x, f1train_y, f1test_y = train_test_split(f1_xdata, f1_ydata, test_size=0.20)
    i_folds=0
    
    #Handler for first dataset size of 8 training
    #Declares k-fold cross validation array of shuffled indexes
    if (len(f1train_x)==8):
        i_folds=4
        kfold = KFold(n_splits=i_folds, shuffle=True)
    else:
        i_folds=10
        kfold = KFold(n_splits=i_folds, shuffle=True)
    
    #Iterate through every node size
    for i_nodes, nodes in enumerate(num_nodes):
        #Build single hidden layer model
        model = Sequential()
        model.add(Dense(nodes, input_shape=(1,), kernel_initializer=keras.initializers.RandomNormal(mean=0., stddev=10), bias_initializer=keras.initializers.RandomNormal(mean=0., stddev=10), activation='sigmoid', name='hiddeninput'))
        model.add(Dense(1, activation='linear', name='output'))
        model.compile(Adam(lr=0.1), loss='mean_squared_error', metrics=['accuracy'])
        #Empty arrays to hold each shuffle error (avg of k-cross errors)
        train_shuffle_errors=np.array([])
        valid_shuffle_errors=np.array([])
        
        #Shuffle 5 times
        for i_shuffle in range(5):
            #Empty arrays to hold each k-cross error
            train_kcross_errors=np.array([])
            valid_kcross_errors=np.array([])
            
            #Perform k-cross validation
            for train, evalu in kfold.split(f1train_x, f1train_y):
                #Training model with callback to early stop
                history=model.fit(f1train_x[train], f1train_y[train], validation_data=(f1train_x[evalu], f1train_y[evalu]), epochs=1000, verbose=0, callbacks=[es])
                #Finding index when total error is the smallest
                total_error=np.array(history.history['val_loss'])+np.array(history.history['loss'])
                i_valid_min=np.argmin(total_error)
                #Add training/validation errors when total error is smallest
                train_kcross_errors=np.append(train_kcross_errors, np.array(history.history['loss'])[i_valid_min])
                valid_kcross_errors=np.append(valid_kcross_errors, np.array(history.history['val_loss'])[i_valid_min])
            #Add averaged k-cross errors to shuffle array
            train_shuffle_errors=np.append(train_shuffle_errors, np.sum(train_kcross_errors)/i_folds)
            valid_shuffle_errors=np.append(valid_shuffle_errors, np.sum(valid_kcross_errors)/i_folds)
        #Add averaged shuffle errors to final array
        final_train_error[i_datasets][i_nodes]=np.sum(train_shuffle_errors)/5
        final_valid_error[i_datasets][i_nodes]=np.sum(valid_shuffle_errors)/5

print(final_train_error)
print(final_valid_error)
# Out:
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A709551F8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A709551F8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# Epoch 00076: early stopping
# Epoch 00088: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00087: early stopping
# Epoch 00076: early stopping
# Epoch 00077: early stopping
# Epoch 00087: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00087: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A71736B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A71736B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# Epoch 00173: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00080: early stopping
# Epoch 00090: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00090: early stopping
# Epoch 00076: early stopping
# Epoch 00076: early stopping
# Epoch 00093: early stopping
# Epoch 00076: early stopping
# Epoch 00094: early stopping
# Epoch 00076: early stopping
# Epoch 00096: early stopping
# Epoch 00076: early stopping
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019
early stopping
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A22E21828> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A22E21828> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# Epoch 00495: early stopping
# Epoch 00385: early stopping
# Epoch 00093: early stopping
# Epoch 00486: early stopping
# Epoch 00137: early stopping
# Epoch 00097: early stopping
# Epoch 00275: early stopping
# Epoch 00112: early stopping
# Epoch 00134: early stopping
# Epoch 00131: early stopping
# Epoch 00104: early stopping
# Epoch 00186: early stopping
# Epoch 00134: early stopping
# Epoch 00192: early stopping
# Epoch 00232: early stopping
# Epoch 00086: early stopping
# Epoch 00077: early stopping
# Epoch 00134: early stopping
# Epoch 00157: early stopping
# Epoch 00225: early stopping
# Epoch 00142: early stopping
# Epoch 00097: early stopping
# Epoch 00088: early stopping
# Epoch 00128: early stopping
# Epoch 00110: early stopping
# Epoch 00158: early stopping
# Epoch 00300: early stopping
# Epoch 00090: early stopping
# Epoch 00164: early stopping
# Epoch 00099: early stopping
# Epoch 00093: early stopping
# Epoch 00101: early stopping
# Epoch 00084: early stopping
# Epoch 00086: early stopping
# Epoch 00386: early stopping
# Epoch 00096: early stopping
# Epoch 00163: early stopping
# Epoch 00105: early stopping
# Epoch 00103: early stopping
# Epoch 00230: early stopping
# Epoch 00156: early stopping
# Epoch 00084: early stopping
# Epoch 00119: early stopping
# Epoch 00179: early stopping
# Epoch 00167: early stopping
# Epoch 00084: early stopping
# Epoch 00081: early stopping
# Epoch 00087: early stopping
# Epoch 00080: early stopping
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A3207B678> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A3207B678> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# Epoch 00081: early stopping
# Epoch 00732: early stopping
# Epoch 00101: early stopping
# Epoch 00087: early stopping
# Epoch 00152: early stopping
# Epoch 00100: early stopping
# Epoch 00089: early stopping
# Epoch 00151: early stopping
# Epoch 00171: early stopping
# Epoch 00128: early stopping
# Epoch 00078: early stopping
# Epoch 00160: early stopping
# Epoch 00078: early stopping
# Epoch 00078: early stopping
# Epoch 00118: early stopping
# Epoch 00253: early stopping
# Epoch 00140: early stopping
# Epoch 00081: early stopping
# Epoch 00195: early stopping
# Epoch 00117: early stopping
# Epoch 00135: early stopping
# Epoch 00271: early stopping
# Epoch 00104: early stopping
# Epoch 00081: early stopping
# Epoch 00161: early stopping
# Epoch 00094: early stopping
# Epoch 00088: early stopping
# Epoch 00076: early stopping
# Epoch 00194: early stopping
# Epoch 00112: early stopping
# Epoch 00161: early stopping
# Epoch 00215: early stopping
# Epoch 00099: early stopping
# Epoch 00078: early stopping
# Epoch 00178: early stopping
# Epoch 00105: early stopping
# Epoch 00190: early stopping
# Epoch 00119: early stopping
# Epoch 00090: early stopping
# Epoch 00091: early stopping
# Epoch 00153: early stopping
# Epoch 00231: early stopping
# Epoch 00115: early stopping
# Epoch 00159: early stopping
# Epoch 00191: early stopping
# Epoch 00093: early stopping
# Epoch 00240: early stopping
# Epoch 00152: early stopping
# Epoch 00145: early stopping
# Epoch 00095: early stopping
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A31831708> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A31831708> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# Epoch 00454: early stopping
# Epoch 00181: early stopping
# Epoch 00187: early stopping
# Epoch 00216: early stopping
# Epoch 00147: early stopping
# Epoch 00204: early stopping
# Epoch 00137: early stopping
# Epoch 00101: early stopping
# Epoch 00129: early stopping
# Epoch 00173: early stopping
# Epoch 00103: early stopping
# Epoch 00131: early stopping
# Epoch 00176: early stopping
# Epoch 00146: early stopping
# Epoch 00174: early stopping
# Epoch 00184: early stopping
# Epoch 00195: early stopping
# Epoch 00082: early stopping
# Epoch 00178: early stopping
# Epoch 00140: early stopping
# Epoch 00192: early stopping
# Epoch 00077: early stopping
# Epoch 00193: early stopping
# Epoch 00217: early stopping
# Epoch 00170: early stopping
# Epoch 00095: early stopping
# Epoch 00116: early stopping
# Epoch 00147: early stopping
# Epoch 00077: early stopping
# Epoch 00215: early stopping
# Epoch 00213: early stopping
# Epoch 00219: early stopping
# Epoch 00083: early stopping
# Epoch 00108: early stopping
# Epoch 00186: early stopping
# Epoch 00135: early stopping
# Epoch 00170: early stopping
# Epoch 00195: early stopping
# Epoch 00081: early stopping
# Epoch 00337: early stopping
# Epoch 00094: early stopping
# Epoch 00135: early stopping
# Epoch 00100: early stopping
# Epoch 00222: early stopping
# Epoch 00136: early stopping
# Epoch 00077: early stopping
# Epoch 00183: early stopping
# Epoch 00094: early stopping
# Epoch 00228: early stopping
# Epoch 00083: early stopping
# [[0.04740811 0.02974543 0.00254735 0.00329944]
#  [0.04222903 0.00503031 0.00580503 0.00095641]
#  [0.05818516 0.01232269 0.00564466 0.00093586]
#  [0.03645256 0.00518094 0.00093799 0.00017042]]
# [[0.0597366  0.03112316 0.0075175  0.01579551]
#  [0.04263658 0.00490838 0.00496266 0.0013236 ]
#  [0.05386484 0.01101796 0.00442636 0.00123509]
#  [0.03477959 0.0050391  0.00104015 0.00010287]]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam


num_datasets=200
num_nodes=100

#Generating data and target data
f1_xdata=np.array(2*np.random.rand(num_datasets)-1)
f1_ydata=np.array(f1_xdata*np.sin(6*np.pi*f1_xdata)*np.exp(-f1_xdata**2))
#Splitting data into 80% train and 20% test
f1train_x, f1test_x, f1train_y, f1test_y = train_test_split(f1_xdata, f1_ydata, test_size=0.20)

#Making model with single hidden layer
model = Sequential()
model.add(Dense(num_nodes, input_shape=(1,), kernel_initializer=keras.initializers.RandomNormal(mean=0., stddev=10), bias_initializer=keras.initializers.RandomNormal(mean=0., stddev=10), activation='sigmoid', name='hiddeninput'))
model.add(Dense(1, activation='linear', name='output'))
model.compile(Adam(lr=0.1), loss='mean_squared_error', metrics=['accuracy'])
#Training model with 1000 epochs
model.fit(f1train_x, f1train_y, epochs=1000, verbose=0)

#Predicting trained model on the test data
ynew = model.predict(f1test_x)

#Plotting
x=np.linspace(-1,1,100)
y=np.array(x*np.sin(6*np.pi*x)*np.exp(-x**2))
plt.plot(x,y, label='original')
plt.scatter(f1test_x,ynew, label='predicted', color='red')
plt.legend()
plt.title('F1 Predicted vs. Original Function')
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()
# Out:
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A447B4AF8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000019A447B4AF8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
